# %%
from brightway2 import *
import bw2data as bd
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # BW setup

# %%
#Set Project
projects.set_current('plca_metals')

# %%
list(databases)
# Out:
# ['biosphere3',
#  'ecoinvent-3.10-cutoff',
#  'NZE_2022',
#  'NZE_2025',
#  'NZE_2030',
#  'NZE_2035',
#  'NZE_2040',
#  'NZE_2045',
#  'NZE_2050',
#  'biosphere3_spatialized_flows',
#  'NZE_2050 regionalized',
#  'SPS_2022',
#  'SPS_2025',
#  'SPS_2030',
#  'SPS_2035',
#  'SPS_2040',
#  'SPS_2045',
#  'SPS_2050',
#  'SPS_2022 regionalized',
#  'SPS_2025 regionalized',
#  'SPS_2030 regionalized',
#  'SPS_2035 regionalized',
#  'SPS_2040 regionalized',
#  'SPS_2045 regionalized',
#  'SPS_2050 regionalized',
#  'NZE_2022 regionalized',
#  'NZE_2025 regionalized',
#  'NZE_2030 regionalized',
#  'NZE_2035 regionalized',
#  'NZE_2040 regionalized',
#  'NZE_2045 regionalized']

# %%
# Import IW+2.1. methods 
IW_METHODS = [method for method in bd.methods if "impact world+" in " ".join(method).lower()]
IW_METHODS
# Out:
# [('IMPACT World+ v2.0.1, footprint version',
#   'climate change',
#   'carbon footprint'),
#  ('IMPACT World+ v2.0.1, footprint version',
#   'ecosystem quality',
#   'remaining ecosystem quality damage'),
#  ('IMPACT World+ v2.0.1, footprint version',
#   'energy resources: non-renewable',
#   'fossil and nuclear energy use'),
#  ('IMPACT World+ v2.0.1, footprint version',
#   'human health',
#   'remaining human health damage'),
#  ('IMPACT World+ v2.0.1, footprint version',
#   'water use',
#   'water scarcity footprint'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Climate change, ecosystem quality, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Climate change, ecosystem quality, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Climate change, human health, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Climate change, human health, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Climate change, long term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Climate change, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Fisheries impact'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Fossil and nuclear energy use'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater acidification'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater acidification'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater ecotoxicity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater ecotoxicity, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater eutrophication'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater eutrophication'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Human toxicity cancer'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity cancer, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity cancer, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Human toxicity non-cancer'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity non-cancer, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity non-cancer, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Ionizing radiations'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Ionizing radiations, ecosystem quality'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Ionizing radiations, human health'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Land occupation, biodiversity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Land occupation, biodiversity'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Land transformation, biodiversity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Land transformation, biodiversity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine acidification, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine acidification, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine ecotoxicity, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Marine eutrophication'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine eutrophication'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Mineral resources use'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Ozone layer depletion'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Ozone layer depletion'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Particulate matter formation'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Particulate matter formation'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Photochemical ozone formation'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Photochemical ozone formation, ecosystem quality'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Photochemical ozone formation, human health'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Terrestrial acidification'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial acidification'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial ecotoxicity, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Thermally polluted water'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Water availability, freshwater ecosystem'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Water availability, human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Water availability, terrestrial ecosystem'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Water scarcity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Total human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Total ecosystem quality')]

# %%
df_iw_methods = pd.DataFrame(IW_METHODS, columns=["Method", "Impact Category", "Subcategory"])
df_iw_methods.to_csv(r'data/iw2.1_methods.csv', index=False)

# %%
# Extract methods for IMPACT World+ Damage 2.1
IMPACT_METHODS_DAMAGE = [
    method for method in IW_METHODS 
    if method[0] == 'IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10'
]
IMPACT_METHODS_DAMAGE
# Out:
# [('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Climate change, ecosystem quality, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Climate change, ecosystem quality, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Climate change, human health, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Climate change, human health, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Fisheries impact'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater acidification'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater ecotoxicity, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Freshwater eutrophication'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity cancer, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity cancer, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity non-cancer, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Human toxicity non-cancer, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Ionizing radiations, ecosystem quality'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Ionizing radiations, human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Land occupation, biodiversity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Land transformation, biodiversity'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine acidification, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine acidification, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine ecotoxicity, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Marine eutrophication'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Ozone layer depletion'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Particulate matter formation'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Photochemical ozone formation, ecosystem quality'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Photochemical ozone formation, human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial acidification'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial ecotoxicity, long term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Terrestrial ecotoxicity, short term'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Thermally polluted water'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Water availability, freshwater ecosystem'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Water availability, human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Water availability, terrestrial ecosystem'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Human health',
#   'Total human health'),
#  ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10',
#   'Ecosystem quality',
#   'Total ecosystem quality')]

# %%
# Extract methods for IMPACT World+ Midpoint 2.1
IMPACT_METHODS_MIDPOINTS = [
    method for method in IW_METHODS 
    if method[0] == 'IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10'
]
IMPACT_METHODS_MIDPOINTS
# Out:
# [('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Climate change, long term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Climate change, short term'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Fossil and nuclear energy use'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater acidification'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater ecotoxicity'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Freshwater eutrophication'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Human toxicity cancer'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Human toxicity non-cancer'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Ionizing radiations'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Land occupation, biodiversity'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Land transformation, biodiversity'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Marine eutrophication'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Mineral resources use'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Ozone layer depletion'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Particulate matter formation'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Photochemical ozone formation'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Terrestrial acidification'),
#  ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10',
#   'Midpoint',
#   'Water scarcity')]

# %%
CC = [
    ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10', 'Midpoint', 'Climate change, long term'),
    ('IMPACT World+ Midpoint 2.1_regionalized for ecoinvent v3.10', 'Midpoint', 'Climate change, short term')
]

# %%
IW_EP = [
    ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10', 'Human health', 'Total human health'),
    ('IMPACT World+ Damage 2.1_regionalized for ecoinvent v3.10', 'Ecosystem quality', 'Total ecosystem quality')
]

# %% [markdown]
# # LCA calculations for IEA energy transition scenarios

# %% [markdown]
# ## Import metal quantities by scenarios and technology

# %%
#Import data from excel file
excel_file = r'data/data_metals.xlsx'
sheet_name = "metals_ei"
df_metals_ei = pd.read_excel(excel_file, sheet_name=sheet_name)

# %%
years = ["2022", "2025", "2030", "2035", "2040", "2045", "2050"]

# %%
#Multiply the quantities by 1e6 to have kilograms instead of kilotons
df_metals_ei[years] *= 1000000

# %%
#Demand by metal and by technology for the scenario NZE
df_NZE = df_metals_ei.loc[df_metals_ei['Scenario'] == 'NZE'].copy()
df_NZE
# Out:
#               Metal            Technology  \
# 0         Aluminium  Electricity Networks
# 2           Arsenic              Solar PV
# 4             Boron                  Wind
# 6           Cadmium              Solar PV
# 8          Chromium                  Wind
# 10           Cobalt       Battery Storage
# 11           Cobalt                    EV
# 12           Cobalt              Hydrogen
# 16           Copper       Battery Storage
# 17           Copper  Electricity Networks
# 18           Copper                    EV
# 19           Copper              Solar PV
# 20           Copper                  Wind
# 26       Dysprosium                    EV
# 27       Dysprosium                  Wind
# 30   Ferromanganese                    EV
# 31   Ferromanganese                  Wind
# 34      Ferronickel              Solar PV
# 35      Ferronickel                  Wind
# 38          Gallium              Solar PV
# 40         Graphite       Battery Storage
# 41         Graphite                    EV
# 44           Indium              Solar PV
# 46          Iridium              Hydrogen
# 48             Lead              Solar PV
# 50          Lithium       Battery Storage
# 51          Lithium                    EV
# 54        Manganese       Battery Storage
# 55        Manganese                    EV
# 58       Molybdenum              Solar PV
# 59       Molybdenum                  Wind
# 62        Neodymium                    EV
# 63        Neodymium                  Wind
# 66           Nickel       Battery Storage
# 67           Nickel                    EV
# 68           Nickel              Hydrogen
# 72         Platinum              Hydrogen
# 74     Praseodymium                    EV
# 75     Praseodymium                  Wind
# 78         Selenium              Solar PV
# 80          Silicon       Battery Storage
# 81          Silicon                    EV
# 82          Silicon              Solar PV
# 86           Silver              Solar PV
# 88        Tellurium              Solar PV
# 90          Terbium                    EV
# 91          Terbium                  Wind
# 94              Tin              Solar PV
# 96         Vanadium       Battery Storage
# 98             Zinc              Solar PV
# 99             Zinc                  Wind
# 102       Zirconium              Hydrogen
#
#                                                 Market  \
# 0             market for aluminium, wrought alloy (SM)
# 2                                    market for arsine
# 4                               market for boric oxide
# 6              market for cadmium, semiconductor-grade
# 8        market for ferrochromium, high-carbon, 68% Cr
# 10                      market for cobalt sulfate (SM)
# 11                      market for cobalt sulfate (SM)
# 12                      market for cobalt sulfate (SM)
# 16                     market for copper, cathode (SM)
# 17                     market for copper, cathode (SM)
# 18                     market for copper, cathode (SM)
# 19                     market for copper, cathode (SM)
# 20                     market for copper, cathode (SM)
# 26                         market for dysprosium oxide
# 27                         market for dysprosium oxide
# 30      market for ferromanganese, high-coal, 74.5% Mn
# 31      market for ferromanganese, high-coal, 74.5% Mn
# 34                              market for ferronickel
# 35                              market for ferronickel
# 38             market for gallium, semiconductor-grade
# 40                  market for graphite, battery grade
# 41                  market for graphite, battery grade
# 44                                   market for indium
# 46   platinum group metal, extraction and refinery ...
# 48                                     market for lead
# 50    market for lithium carbonate, battery grade (SM)
# 51    market for lithium carbonate, battery grade (SM)
# 54                        market for manganese sulfate
# 55                        market for manganese sulfate
# 58                              market for molybdenite
# 59                              market for molybdenite
# 62                          market for neodymium oxide
# 63                          market for neodymium oxide
# 66                     market for nickel, class 1 (SM)
# 67                     market for nickel, class 1 (SM)
# 68                     market for nickel, class 1 (SM)
# 72                                 market for platinum
# 74                       market for praseodymium oxide
# 75                       market for praseodymium oxide
# 78                                 market for selenium
# 80             market for silicon, metallurgical grade
# 81             market for silicon, metallurgical grade
# 82             market for silicon, metallurgical grade
# 86                                   market for silver
# 88           market for tellurium, semiconductor-grade
# 90                            market for terbium oxide
# 91                            market for terbium oxide
# 94                                      market for tin
# 96                       vanadium pentoxide production
# 98                                     market for zinc
# 99                                     market for zinc
# 102                         market for zirconium oxide
#
#                        Reference Product Location Scenario          2022  \
# 0               aluminium, wrought alloy    World      NZE  1.035700e+10
# 2                                 arsine      GLO      NZE  0.000000e+00
# 4                            boric oxide      GLO      NZE  1.586180e+05
# 6           cadmium, semiconductor-grade      GLO      NZE  4.208430e+05
# 43         Graphite       Battery Storage
# 45           Indium              Solar PV
# 47          Iridium              Hydrogen
# 49             Lead              Solar PV
# 52          Lithium                    EV
# 53          Lithium       Battery Storage
# 56        Manganese                    EV
# 57        Manganese       Battery Storage
# 60       Molybdenum              Solar PV
# 61       Molybdenum                  Wind
# 64        Neodymium                  Wind
# 65        Neodymium                    EV
# 69           Nickel                    EV
# 70           Nickel       Battery Storage
# 71           Nickel              Hydrogen
# 73         Platinum              Hydrogen
# 76     Praseodymium                  Wind
# 77     Praseodymium                    EV
# 79         Selenium              Solar PV
# 83          Silicon              Solar PV
# 84          Silicon                    EV
# 85          Silicon       Battery Storage
# 87           Silver              Solar PV
# 89        Tellurium              Solar PV
# 92          Terbium                  Wind
# 93          Terbium                    EV
# 95              Tin              Solar PV
# 97         Vanadium       Battery Storage
# 100            Zinc              Solar PV
# 101            Zinc                  Wind
# 103       Zirconium              Hydrogen
#
#                                                 Market  \
# 1             market for aluminium, wrought alloy (SM)
# 3                                    market for arsine
# 5                               market for boric oxide
# 7              market for cadmium, semiconductor-grade
# 9        market for ferrochromium, high-carbon, 68% Cr
# 13                      market for cobalt sulfate (SM)
# 14                      market for cobalt sulfate (SM)
# 15                      market for cobalt sulfate (SM)
# 21                     market for copper, cathode (SM)
# 22                     market for copper, cathode (SM)
# 23                     market for copper, cathode (SM)
# 24                     market for copper, cathode (SM)
# 25                     market for copper, cathode (SM)
# 28                         market for dysprosium oxide
# 29                         market for dysprosium oxide
# 32      market for ferromanganese, high-coal, 74.5% Mn
# 33      market for ferromanganese, high-coal, 74.5% Mn
# 36                              market for ferronickel
# 37                              market for ferronickel
# 39             market for gallium, semiconductor-grade
# 42                  market for graphite, battery grade
# 43                  market for graphite, battery grade
# 45                                   market for indium
# 47   platinum group metal, extraction and refinery ...
# 49                                     market for lead
# 52         market for lithium carbonate, battery grade
# 53         market for lithium carbonate, battery grade
# 56                        market for manganese sulfate
# 57                        market for manganese sulfate
# 60                              market for molybdenite
# 61                              market for molybdenite
# 64                          market for neodymium oxide
# 65                          market for neodymium oxide
# 69                     market for nickel, class 1 (SM)
# 70                     market for nickel, class 1 (SM)
# 71                     market for nickel, class 1 (SM)
# 73                                 market for platinum
# 76                       market for praseodymium oxide
# 77                       market for praseodymium oxide
# 79                                 market for selenium
# 83             market for silicon, metallurgical grade
# 84             market for silicon, metallurgical grade
# 85             market for silicon, metallurgical grade
# 87                                   market for silver
# 89           market for tellurium, semiconductor-grade
# 92                            market for terbium oxide
# 93                            market for terbium oxide
# 95                                      market for tin
# 97                       vanadium pentoxide production
# 100                                    market for zinc
# 101                                    market for zinc
# 103                         market for zirconium oxide
#
#                        Reference Product Location Scenario          2022  \
# 1               aluminium, wrought alloy    World      SPS  1.035700e+10
# 3                                 arsine      GLO      SPS  0.000000e+00
# 5                            boric oxide      GLO      SPS  1.586180e+05
# 7           cadmium, semiconductor-grade      GLO      SPS  4.208430e+05
# 9     ferrochromium, high-carbon, 68% Cr      GLO      SPS  5.031600e+07
# 13                        cobalt sulfate    World      SPS  6.456060e+07
# 14                        cobalt sulfate    World      SPS  3.588530e+06
# 15                        cobalt sulfate    World      SPS  1.073460e+04
# 21                       copper, cathode    World      SPS  6.816450e+08
# 22                       copper, cathode    World      SPS  3.937920e+08
# 23                       copper, cathode    World      SPS  3.733310e+08
# 24                       copper, cathode    World      SPS  2.044680e+07
# 25                       copper, cathode    World      SPS  4.181610e+09
# 28                      dysprosium oxide      GLO      SPS  6.280630e+05
# 29                      dysprosium oxide      GLO      SPS  4.125670e+05
# 32   ferromanganese, high-coal, 74.5% Mn      GLO      SPS  7.999530e+07
# 33   ferromanganese, high-coal, 74.5% Mn      GLO      SPS  3.768480e+07
# 36                           ferronickel      GLO      SPS  2.521000e+05
# 37                           ferronickel      GLO      SPS  3.653810e+07
# 39          gallium, semiconductor-grade      GLO      SPS  8.685480e+03
# 42               graphite, battery grade       CN      SPS  5.572010e+08
# 43               graphite, battery grade       CN      SPS  2.983980e+07
# 45                                indium      GLO      SPS  3.257060e+04
# 47                               iridium       RU      SPS  3.138120e+02
# 49                                  lead      GLO      SPS  1.163540e+06
# 52      lithium carbonate, battery grade    World      SPS  6.973900e+07
# 53      lithium carbonate, battery grade    World      SPS  3.435360e+06
# 56                     manganese sulfate      GLO      SPS  3.768480e+07
# 57                     manganese sulfate      GLO      SPS  3.227310e+06
# 60                           molybdenite      GLO      SPS  1.433320e+05
# 61                           molybdenite      GLO      SPS  1.053010e+07
# 64                       neodymium oxide      GLO      SPS  5.806000e+06
# 65                       neodymium oxide      GLO      SPS  3.961940e+06
# 69                       nickel, class 1    World      SPS  3.258310e+08
# 70                       nickel, class 1    World      SPS  8.911240e+06
# 71                       nickel, class 1    World      SPS  1.766110e+06
# 73                              platinum      GLO      SPS  1.156640e+03
# 76                    praseodymium oxide      GLO      SPS  9.522340e+05
# 77                    praseodymium oxide      GLO      SPS  5.942920e+05
# 79                              selenium      GLO      SPS  7.599800e+04
# 83          silicon, metallurgical grade      GLO      SPS  7.563270e+08
# 84          silicon, metallurgical grade      GLO      SPS  8.699820e+06
# 85          silicon, metallurgical grade      GLO      SPS  6.996850e+04
# 87                                silver      GLO      SPS  3.831000e+06
# 89        tellurium, semiconductor-grade      GLO      SPS  4.225430e+05
# 92                         terbium oxide      GLO      SPS  2.150060e+05
# 93                         terbium oxide      GLO      SPS  8.060630e+04
# 95                                   tin      GLO      SPS  1.202190e+06
# 97                    vanadium pentoxide       ZA      SPS  0.000000e+00
# 100                                 zinc      GLO      SPS  6.059460e+06
# 101                                 zinc      GLO      SPS  5.610260e+08
# 103                      zirconium oxide      GLO      SPS  2.397030e+05
#
#              2025          2030          2035          2040          2045  \
# 1    1.160600e+10  1.452700e+10  1.448200e+10  1.417400e+10  1.494300e+10
# 3    0.000000e+00  1.903290e+05  1.084830e+06  6.381790e+06  7.385250e+06
# 5    1.757780e+05  3.149190e+05  2.877880e+05  2.597290e+05  3.295440e+05
# 7    4.202920e+05  3.975620e+05  3.953310e+05  4.115000e+05  4.659760e+05
# 9    5.417720e+07  7.267500e+07  7.067570e+07  6.586560e+07  8.129220e+07
# 13   6.637010e+07  7.393740e+07  7.767280e+07  1.053090e+08  1.339870e+08
# 85   1.849650e+05  1.132500e+06  2.696400e+06  4.903640e+06  6.398260e+06
# 87   4.030750e+06  4.078090e+06  3.431210e+06  2.852450e+06  2.438560e+06
# 89   4.249870e+05  3.726920e+05  3.643520e+05  3.651070e+05  3.816850e+05
# 92   2.365100e+05  4.014990e+05  3.705980e+05  3.361170e+05  4.265560e+05
# 93   1.484030e+05  2.524070e+05  3.135970e+05  3.907350e+05  4.518970e+05
# 95   1.379830e+06  1.642190e+06  1.674380e+06  1.762030e+06  2.039080e+06
# 97   0.000000e+00  1.537720e+07  7.443010e+07  2.206050e+08  2.428860e+08
# 100  6.954830e+06  8.277210e+06  8.439450e+06  8.881200e+06  1.027770e+07
# 101  6.034240e+08  7.993860e+08  7.773970e+08  7.230940e+08  8.922840e+08
# 103  3.294340e+05  7.188360e+05  5.740940e+05  5.158410e+05  5.575710e+05
#
#              2050
# 1    1.434300e+10
# 3    8.349830e+06
# 5    4.082260e+05
# 7    5.035290e+05
# 9    9.007150e+07
# 13   1.456130e+08
# 14   0.000000e+00
# 15   4.953660e+03
# 21   1.261660e+09
# 22   7.206340e+08
# 23   1.345870e+09
# 24   2.197240e+08
# 25   6.982320e+09
# 28   1.185500e+06
# 29   2.234850e+06
# 32   1.407870e+08
# 33   4.969720e+08
# 36   4.718550e+05
# 37   6.114890e+07
# 39   3.342090e+06
# 42   1.077400e+09
# 43   2.451520e+08
# 45   8.133910e+04
# 47   1.476520e+02
# 49   2.195730e+06
# 52   4.658420e+08
# 53   2.459390e+07
# 56   4.969720e+08
# 57   0.000000e+00
# 60   2.453480e+05
# 61   1.880300e+07
# 64   1.133370e+07
# 65   2.287910e+07
# 69   1.579680e+09
# 70   0.000000e+00
# 71   5.664450e+06
# 73   2.026380e+04
# 76   2.174750e+06
# 77   3.431870e+06
# 79   5.203570e+04
# 83   9.868370e+08
# 84   3.734850e+08
# 85   6.136790e+06
# 87   1.787450e+06
# 89   3.821630e+05
# 92   5.212620e+05
# 93   4.741630e+05
# 95   2.305400e+06
# 97   2.329600e+08
# 100  1.162000e+07
# 101  9.851830e+08
# 103  7.750650e+05

# %%
#df_NZE.to_csv(r'data/df_NZE.csv', index=False)
#df_SPS.to_csv(r'data/df_SPS.csv', index=False)

# %%
# Total demand by metal, for all technologies for the NZE scenario
df_NZE_all = df_NZE.groupby('Metal')[years].sum()

# %%
# Total demand by metal, for all technologies for the SPS scenario
df_SPS_all = df_SPS.groupby('Metal')[years].sum()

# %% [markdown]
# ## LCA calculations

# %% [markdown]
# Create a dictionary with all the EI activities (for each metals) and their keys

# %%
def setup_activities_dict(df, scenario_prefix):
    """
    Create a dictionary mapping (scenario, year, metal, technology) to Brightway activities.
    """
    activities_dict = {}
    
    for index, row in df.iterrows():
        metal = row["Metal"]
        market = row["Market"]
        product = row["Reference Product"]
        location = row["Location"]
        
        for year in years:
            database_name = f"{scenario_prefix}_{year} regionalized"  # Select the appropriate database
            activity_name = (scenario_prefix, year, metal, row["Technology"])
            search_criteria = market
            
            try:
                activities = Database(database_name).search(search_criteria, limit=1000)
                filtered_activities = [
                    i for i in activities if i["name"] == search_criteria
                    and i["location"] == location
                    and i["reference product"] == product
                ]
                
                if filtered_activities:
                    activities_dict[activity_name] = filtered_activities[0]
                else:
                    activities_dict[activity_name] = None
            except:
                activities_dict[activity_name] = None
    
    return activities_dict

# %%
sps_activities_dict = setup_activities_dict(df_SPS, scenario_prefix='SPS')
nze_activities_dict = setup_activities_dict(df_NZE, scenario_prefix='NZE')

# %%
def calculate_lca(df, activities_dict, scenario_prefix, lcia_methods):
    """
    Perform LCA calculations for different scenarios, years, metals, and technologies.
    Returns a DataFrame with results disaggregated.
    """
    results = []
    
    for index, row in df.iterrows():
        metal = row["Metal"]
        technology = row["Technology"]
        
        for year in years:
            quantity = row[str(year)]  # Get the metal quantity for the year
            activity_name = (scenario_prefix, year, metal, technology)
            activity = activities_dict.get(activity_name, None)
            
            if activity:
                impact_results = {}
                
                for method in lcia_methods:
                    try:
                        lca = LCA({activity: quantity}, method)
                        lca.lci()
                        lca.lcia()
                        impact_results[method[2]] = lca.score
                    except:
                        impact_results[method[2]] = np.nan  # Assign NaN if calculation fails
                
                results.append({
                    "Scenario": scenario_prefix,
                    "Year": year,
                    "Metal": metal,
                    "Technology": technology,
                    **impact_results
                })
    
    return pd.DataFrame(results)

# %%
def calculate_lca_optimized(df, activities_dict, scenario_prefix, lcia_methods):
    """
    Optimized LCA calculations for different scenarios, years, metals, and technologies.
    """
    results = []
    
    for index, row in df.iterrows():
        metal = row["Metal"]
        technology = row["Technology"]
        
        for year in years:
            quantity = row[str(year)]  # Get the metal quantity for the year
            activity_name = (scenario_prefix, year, metal, technology)
            activity = activities_dict.get(activity_name, None)
            
            if activity:
                impact_results = {}

                try:
                    # Initialize LCA object once per activity
                    lca = LCA({activity: quantity}, lcia_methods[0])  # Use first method as reference
                    lca.lci()

                    for method in lcia_methods:
                        lca.switch_method(method)  # Switch to a new impact method without recalculating LCI
                        lca.lcia()
                        impact_results[method[2]] = lca.score
                
                except:
                    for method in lcia_methods:
                        impact_results[method[2]] = np.nan  # Assign NaN if calculation fails

                results.append({
                    "Scenario": scenario_prefix,
                    "Year": year,
                    "Metal": metal,
                    "Technology": technology,
                    **impact_results
                })
    
    return pd.DataFrame(results)

# %%
df_sps_damage = calculate_lca_optimized(df_SPS, sps_activities_dict, scenario_prefix='SPS', lcia_methods=IMPACT_METHODS_DAMAGE)

# %%
df_sps_damage
# Out:
#     Scenario  Year      Metal            Technology  \
# 0        SPS  2022  Aluminium  Electricity Networks
# 1        SPS  2025  Aluminium  Electricity Networks
# 2        SPS  2030  Aluminium  Electricity Networks
# 3        SPS  2035  Aluminium  Electricity Networks
# 4        SPS  2040  Aluminium  Electricity Networks
# ..       ...   ...        ...                   ...
# 345      SPS  2030  Zirconium              Hydrogen
# 346      SPS  2035  Zirconium              Hydrogen
# 347      SPS  2040  Zirconium              Hydrogen
# 348      SPS  2045  Zirconium              Hydrogen
# 349      SPS  2050  Zirconium              Hydrogen
#
#      Climate change, ecosystem quality, long term  \
# 0                                    4.561995e+10
# 1                                    4.370999e+10
# 2                                    4.609567e+10
# 3                                    3.993314e+10
# 4                         4410.079036
# ..                                ...
# 345                          1.557567
# 346                          1.240771
# 347                          1.113369
# 348                          1.201580
# 349                          1.668757
#
#      Water availability, terrestrial ecosystem  Total human health  \
# 0                                 4.394529e+06       980519.946440
# 1                                 4.054055e+06       941758.449719
# 2                                 4.090366e+06       997309.699880
# 3                                 3.382868e+06       869338.936731
# 4                                 2.712354e+06       741482.911595
# ..                                         ...                 ...
# 345                               2.229144e+03           19.628006
# 346                               1.771698e+03           13.995715
# 347                               1.585694e+03           11.242318
# 348                               1.709151e+03           10.874702
# 349                               2.371982e+03           13.830994
#
#      Total ecosystem quality
# 0               1.080706e+11
# 1               1.048242e+11
# 2               1.125863e+11
# 3               9.924247e+10
# 4               8.562836e+10
# ..                       ...
# 345             3.193359e+06
# 346             2.379546e+06
# 347             2.003706e+06
# 348             2.036938e+06
# 349             2.704012e+06
#
# [350 rows x 39 columns]

# %%
df_sps_midpoints = calculate_lca_optimized(df_SPS, sps_activities_dict, scenario_prefix='SPS', lcia_methods=IMPACT_METHODS_MIDPOINTS)

# %%
df_sps_midpoints
# Out:
#     Scenario  Year      Metal            Technology  \
# 0        SPS  2022  Aluminium  Electricity Networks
# 1        SPS  2025  Aluminium  Electricity Networks
# 2        SPS  2030  Aluminium  Electricity Networks
# 3        SPS  2035  Aluminium  Electricity Networks
# 4        SPS  2040  Aluminium  Electricity Networks
# ..       ...   ...        ...                   ...
# 345      SPS  2030  Zirconium              Hydrogen
# 346      SPS  2035  Zirconium              Hydrogen
# 347      SPS  2040  Zirconium              Hydrogen
# 348      SPS  2045  Zirconium              Hydrogen
# 349      SPS  2050  Zirconium              Hydrogen
#
#      Climate change, long term  Climate change, short term  \
# 0                 1.107812e+11                1.186879e+11
# 1                 1.060498e+11                1.132015e+11
# 2                 1.117276e+11                1.188163e+11
# 3                 9.670156e+10                1.024765e+11
# 4                 8.159636e+10                8.608936e+10
# ..                         ...                         ...
# 345               1.873715e+06                2.007657e+06
# 346               1.296720e+06                1.389769e+06
# 347               1.003442e+06                1.073842e+06
# 348               9.314636e+05                9.934169e+05
# 349               1.139269e+06                1.209635e+06
#
#      Fossil and nuclear energy use  Freshwater acidification  \
# 0                     1.126542e+12              3.727916e+08
# 1                     1.095214e+12              3.898258e+08
# 2                     1.158454e+12              4.531021e+08
# 3                     1.004405e+12              4.254425e+08
# 4                     8.487728e+11              3.990486e+08
# ..                             ...                       ...
# 345                   2.599659e+07              8.891439e+03
# 346                   1.823057e+07              6.656371e+03
# 347                   1.428867e+07              5.751632e+03
# 348                   1.344348e+07              6.054039e+03
# 349                   1.668638e+07              8.219127e+03
#
#      Freshwater ecotoxicity  Freshwater eutrophication  ...  \
# 0              3.275332e+13              701373.309649  ...
# 1              3.238743e+13              700370.431057  ...
# 2              3.593218e+13              798322.179381  ...
# 3              3.256987e+13              747078.764840  ...
# 4              2.895157e+13              686358.616894  ...
# ..                      ...                        ...  ...
# 345            5.754033e+08                 147.660549  ...
# 346            4.232053e+08                 117.881293  ...
# 347            3.514296e+08                 106.125512  ...
# 348            3.497659e+08                 114.871439  ...
# 349            4.598424e+08                 159.976924  ...
#
#      Ionizing radiations  Land occupation, biodiversity  \
# 0           3.725555e+11                   1.292869e+09
# 1           4.359988e+11                   1.348095e+09
# 2           5.225124e+11                   1.604623e+09
# 3           5.019137e+11                   1.559732e+09
# 4           4.783271e+11                   1.500493e+09
# ..                   ...                            ...
# 345         1.964031e+07                   5.185540e+05
# 346         1.396699e+07                   4.178935e+05
# 347         1.127902e+07                   3.806994e+05
# 348         1.102349e+07                   4.172779e+05
# 349         1.419429e+07                   5.879453e+05
#
#      Land transformation, biodiversity  Marine eutrophication  \
# 0                         6.334728e+06           7.747833e+06
# 1                         7.281226e+06           7.560159e+06
# 2                         9.554732e+06           8.216924e+06
# 3                         9.898360e+06           7.356988e+06
# 4                         9.974422e+06           6.478276e+06
# ..                                 ...                    ...
# 345                       6.087039e+03           2.979087e+02
# 346                       4.867470e+03           2.280343e+02
# 347                       4.378647e+03           1.978923e+02
# 348                       4.734812e+03           2.075571e+02
# 349                       6.580396e+03           2.824229e+02
#
#      Mineral resources use  Ozone layer depletion  \
# 0             6.037950e+08             876.480440
# 1             6.482658e+08             921.209987
# 2             7.801004e+08            1059.764478
# 3             7.593087e+08             988.015251
# 4             7.228783e+08             914.302959
# ..                     ...                    ...
# 345           8.809398e+05               0.193706
# 346           7.037224e+05               0.153663
# 347           6.323800e+05               0.138596
# 348           6.836267e+05               0.148594
# 349           9.506107e+05               0.205243
#
#      Particulate matter formation  Photochemical ozone formation  \
# 0                    1.034656e+08                   1.983526e+08
# 1                    9.792598e+07                   1.943098e+08
# 2                    1.023001e+08                   2.110865e+08
# 3                    8.929291e+07                   1.891677e+08
# 4                    7.734625e+07                   1.669520e+08
# ..                            ...                            ...
# 345                  2.583516e+03                   5.873839e+03
# 346                  1.902155e+03                   4.368211e+03
# 347                  1.596043e+03                   3.697946e+03
# 348                  1.613303e+03                   3.798779e+03
# 349                  2.136482e+03                   5.094182e+03
#
#      Terrestrial acidification  Water scarcity
# 0                 6.193024e+08    1.328265e+10
# 1                 6.219208e+08    1.381816e+10
# 2                 6.966283e+08    1.558064e+10
# 3                 6.387024e+08    1.445071e+10
# 4                 5.796131e+08    1.308186e+10
# ..                         ...             ...
# 345               9.301120e+03    3.887305e+06
# 346               6.718426e+03    3.066093e+06
# 347               5.551142e+03    2.729331e+06
# 348               5.510405e+03    2.926264e+06
# 349               7.178935e+03    4.043171e+06
#
# [350 rows x 22 columns]

# %%
df_nze_damage = calculate_lca_optimized(df_NZE, nze_activities_dict, scenario_prefix='NZE', lcia_methods=IMPACT_METHODS_DAMAGE)

# %%
df_nze_midpoints = calculate_lca_optimized(df_NZE, nze_activities_dict, scenario_prefix='NZE', lcia_methods=IMPACT_METHODS_MIDPOINTS)

# %%
# Save to csv to the result folder
df_sps_damage.to_csv(r'results/df_sps_damage_regionalized.csv', index=False)
df_sps_midpoints.to_csv(r'results/df_sps_midpoints_regionalized.csv', index=False)
df_nze_damage.to_csv(r'results/df_nze_damage_regionalized.csv', index=False)
df_nze_midpoints.to_csv(r'results/df_nze_midpoints_regionalized.csv', index=False)

# %% [markdown]
# # LCA calculation for the all economy
