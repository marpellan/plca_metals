# %%
import pandas as pd
import os

# %%
folder_path = r"C:\Users\mp_ma\OneDrive - polymtlus\Desktop\POST_DOC\Project\plca_metals\New_version_marin\data_minerals"  # Change this to the actual path

# %% [markdown]
# # Lists of minerals covered in the IEA scenarios and USGS MCS2024

# %%
# List of metals included in the IEA scenarios
etm_iea = [
    "aluminum",
    "arsenic",
    "boron",
    "cadmium",
    "chromium",
    "cobalt",
    "copper",
    "dysprosium",
    "ferromanganese",
    "ferronickel",
    "gallium",
    "graphite",
    "indium",
    "iridium",
    "lead",
    "lithium",
    "manganese",
    "molybdenum",
    "neodymium",
    "nickel",
    "platinum",
    "praseodymium",
    "selenium",
    "silicon",
    "silver",
    "tellurium",
    "terbium",
    "tin",
    "vanadium",
    "zinc",
    "zirconium"
]

# %%
# List of minerals included in the World Mining Data 2024
wmd_2024 = [
    "aluminium",
    "antimony",
    "arsenic",
    "asbestos",
    "baryte",
    "bauxite",
    "bentonite",
    "beryllium",
    "bismuth",
    "boron",
    "cadmium",
    "chromium",
    "coal (tot)",
    "cobalt",
    "coking coal",
    "copper",
    "diam. (gem)",
    "diam. (ind)",
    "diatomite",
    "feldspar",
    "fluorspar",
    "gallium",
    "germanium",
    "gold",
    "graphite",
    "gypsum",
    "hard coal (tot)",
    "indium",
    "iron",
    "kaolin",
    "lead",
    "lignite",
    "lithium",
    "magnesite",
    "manganese",
    "mercury",
    "molybdenum",
    "nat. gas",
    "nickel",
    "niobium",
    "oil sands*",
    "oil shales",
    "palladium",
    "perlite",
    "petroleum",
    "phosphates",
    "platinum",
    "potash",
    "rare earths",
    "rhenium",
    "rhodium",
    "salt",
    "selenium",
    "silver",
    "steam coal",
    "sulfur",
    "talc",
    "tantalum",
    "tellurium",
    "tin",
    "titanium",
    "tungsten",
    "uranium",
    "vanadium",
    "vermiculite",
    "zinc",
    "zircon"
]

# %%
# List of minerals included in the USGS Mineral Commodities 2024
usgs_minerals_2024 = [
    "abrasives", "fluorspar", "mercury", "silicon",
    "aluminum", "gallium", "mica", "silver",
    "antimony", "garnet", "molybdenum", "soda ash",
    "arsenic", "gemstones", "nickel", "stone",
    "asbestos", "germanium", "niobium", "strontium",
    "barite", "gold", "nitrogen", "sulfur",
    "bauxite", "graphite", "palladium", "talc",
    "beryllium", "gypsum", "peat", "tantalum",
    "bismuth", "hafnium", "perlite", "tellurium",
    "boron", "helium", "phosphate rock", "thallium",
    "bromine", "indium", "platinum", "thorium",
    "cadmium", "iodine", "potash", "tin",
    "cement", "iron and steel", "pumice", "titanium",
    "cesium", "iron ore", "quartz", "tungsten",
    "chromium", "iron oxide pigments", "rare earths", "vanadium",
    "clays", "kyanite", "rhenium", "vermiculite",
    "cobalt", "lead", "rubidium", "wollastonite",
    "copper", "lime", "salt", "yttrium",
    "diamond", "lithium", "sand and gravel", "zeolites",
    "diatomite", "magnesium", "scandium", "zinc",
    "feldspar", "manganese", "selenium", "zirconium"
]

# %%
csv_to_usgs_dict = {
    "mcs2024-abras_world.csv": "abrasives",
    "mcs2024-alumi_world.csv": "aluminum",
    "mcs2024-antim_world.csv": "antimony",
    "mcs2024-arsen_world.csv": "arsenic",
    "mcs2024-asbes_world.csv": "asbestos",
    "mcs2024-barit_world.csv": "barite",
    "mcs2024-bauxi_world.csv": "bauxite",
    "mcs2024-beryl_world.csv": "beryllium",
    "MCS2024-bismu_world.csv": "bismuth",
    "mcs2024-boron_world.csv": "boron",
    "mcs2024-bromi_world.csv": "bromine",
    "mcs2024-cadmi_world.csv": "cadmium",
    "mcs2024-cemen_world.csv": "cement",
    "mcs2024-chrom_world.csv": "chromium",
    "mcs2024-clays_world.csv": "clays",
    "mcs2024-cobal_world.csv": "cobalt",
    "mcs2024-coppe_world.csv": "copper",
    "mcs2024-diamo_world.csv": "diamond",
    "mcs2024-diato_world.csv": "diatomite",
    "mcs2024-felds_world.csv": "feldspar",
    "mcs2024-feore_world.csv": "iron ore",
    "mcs2024-fepig_world.csv": "iron oxide pigments",
    "mcs2024-feste_world.csv": "iron and steel",
    "mcs2024-fluor_world.csv": "fluorspar",
    "mcs2024-galli_world.csv": "gallium",
    "mcs2024-garne_world.csv": "garnet",
    "mcs2024-gemst_world.csv": "gemstones",
    "mcs2024-germa_world.csv": "germanium",
    "mcs2024-gold_world.csv": "gold",
    "mcs2024-graph_world.csv": "graphite",
    "mcs2024-gypsu_world.csv": "gypsum",
    "mcs2024-heliu_world.csv": "helium",
    "mcs2024-indiu_world.csv": "indium",
    "mcs2024-iodin_world.csv": "iodine",
    "mcs2024-kyani_world.csv": "kyanite",
    "mcs2024-lead_world.csv": "lead",
    "mcs2024-lime_world.csv": "lime",
    "mcs2024-lithi_world.csv": "lithium",
    "mcs2024-manga_world.csv": "manganese",
    "mcs2024-mercu_world.csv": "mercury",
    "mcs2024-mgcomp_world.csv": "magnesium",
    "mcs2024-mgmet_world.csv": "magnesium metal",
    "mcs2024-mica_world.csv": "mica",
    "mcs2024-molyb_world.csv": "molybdenum",
    "mcs2024-nicke_world.csv": "nickel",
    "mcs2024-niobi_world.csv": "niobium",
    "mcs2024-nitro_world.csv": "nitrogen",
    "mcs2024-peat_world.csv": "peat",
    "mcs2024-perli_world.csv": "perlite",
    "mcs2024-phosp_world.csv": "phosphate rock",
    "mcs2024-plati_world.csv": "platinum",
    "mcs2024-potas_world.csv": "potash",
    "mcs2024-raree_world.csv": "rare earths",
    "mcs2024-rheni_world.csv": "rhenium",
    "mcs2024-salt_world.csv": "salt",
    "mcs2024-sandi_world.csv": "sand and gravel",
    "mcs2024-selen_world.csv": "selenium",
    "mcs2024-silve_world.csv": "silver",
    "mcs2024-simet_world.csv": "silicon",
    "mcs2024-sodaa_world.csv": "soda ash",
    "mcs2024-stond_world.csv": "stone",
    "mcs2024-stron_world.csv": "strontium",
    "mcs2024-sulfu_world.csv": "sulfur",
    "mcs2024-talc_world.csv": "talc",
    "mcs2024-tanta_world.csv": "tantalum",
    "mcs2024-tellu_world.csv": "tellurium",
    "mcs2024-timin_world.csv": "tin",
    "mcs2024-tin_world.csv": "tin",
    "mcs2024-titan_world.csv": "titanium",
    "mcs2024-tungs_world.csv": "tungsten",
    "mcs2024-vanad_world.csv": "vanadium",
    "mcs2024-vermi_world.csv": "vermiculite",
    "mcs2024-wolla_world.csv": "wollastonite",
    "mcs2024-zeoli_world.csv": "zeolites",
    "mcs2024-zinc_world.csv": "zinc",
    "mcs2024-zirco_world.csv": "zirconium"
}

# %%
unique_minerals = sorted(set(etm_iea + usgs_minerals_2024))

df = pd.DataFrame(unique_minerals, columns=["Mineral"])
df["In_IEA"] = df["Mineral"].isin(etm_iea)
df["In_USGS_MCS2024"] = df["Mineral"].isin(usgs_minerals_2024)
df["In_WMD_2024"] = df["Mineral"].isin(usgs_minerals_2024)

# %%
df
# Out:
#          Mineral  In_IEA  In_USGS_MCS2024  In_WMD_2024
# 0      abrasives   False             True         True
# 1       aluminum    True             True         True
# 2       antimony   False             True         True
# 3        arsenic    True             True         True
# 4       asbestos   False             True         True
# ..           ...     ...              ...          ...
# 86  wollastonite   False             True         True
# 87       yttrium   False             True         True
# 88      zeolites   False             True         True
# 89          zinc    True             True         True
# 90     zirconium    True             True         True
#
# [91 rows x 4 columns]

# %%
df.to_csv(r'iea_usgs_wmd_data_availability.csv', index=False)

# %%
# Filter for minerals that are in IEA but not in USGS
iea_only_minerals = df[(df["In_IEA"] == True) & (df["In_USGS_MCS2024"] == False) | (df["In_WMD_2024"] == False)]
iea_only_minerals
# Out:
#            Mineral  In_IEA  In_USGS_MCS2024  In_WMD_2024
# 20      dysprosium    True            False        False
# 22  ferromanganese    True            False        False
# 23     ferronickel    True            False        False
# 36         iridium    True            False        False
# 49       neodymium    True            False        False
# 59    praseodymium    True            False        False
# 78         terbium    True            False        False

# %% [markdown]
# # Extract USGS csv data and tranform it to a df

# %%
def extract_world_rows(folder_path):
    all_dfs = []
    
    # Loop through all files in the folder
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):  # Process only CSV files
            file_path = os.path.join(folder_path, file)
            df = pd.read_csv(file_path)
            
            
            # Check if required columns exist
            required_columns = {'Source', 'Country'}
            if not required_columns.issubset(df.columns) or len(df.columns) < 4:
                continue  # Skip files missing essential columns
            
            world_df = df[df['Country'].str.contains("World", na=False, case=False)].copy()
            
            # Extract column names for production values
            production_2022_col = df.columns[3]
            production_2023_col = df.columns[4] if len(df.columns) > 4 else None
            
            # Rename columns to standard format
            world_df.rename(columns={
                production_2022_col: 'Production_2022',
                production_2023_col: 'Production_2023'
            }, inplace=True)
            
            # Add unit column
            world_df['Unit'] = production_2022_col.replace("Prod_", "").replace("Cap_", "")
            
            # Add source file column
            world_df['Source_File'] = file
            
            # Ensure 'Type' column exists, fill missing with 'Unknown'
            if 'Type' not in world_df.columns:
                world_df['Type'] = 'Unknown'
            
            # Keep only required columns
            keep_columns = ['Source', 'Country', 'Type', 'Production_2022', 'Production_2023', 'Unit', 'Source_File']
            world_df = world_df[keep_columns]
            
            # Append to list
            all_dfs.append(world_df)
    
    # Combine all DataFrames into a single DataFrame
    combined_df = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
    
    combined_df["Mineral"] = combined_df["Source_File"].map(csv_to_usgs_dict)
    combined_df.drop(columns=["Source_File"], inplace=True)

    return combined_df

# %%
df_usgs_world = extract_world_rows(folder_path=folder_path + r'/USGS/world')
df_usgs_world
# Out:
#       Source                  Country  \
# 0    MCS2024    World total (rounded)
# 1    MCS2024    World total (rounded)
# 2   MCS 2024    World total (rounded)
# 3    MCS2024  World total (rounded)10
# 4    MCS2024    World total (rounded)
# ..       ...                      ...
# 86   MCS2024    World total (rounded)
# 87   MCS2024    World total (rounded)
# 88       NaN    World total (rounded)
# 89   MCS2024    World total (rounded)
# 90   MCS2024    World total (rounded)
#
#                                                  Type Production_2022  \
# 0                Plant capacity, fused aluminum oxide         1310000
# 1                     Plant capacity, silicon carbide         1000000
# 2                        Smelter production, aluminum         68400.0
# 3                 Mine production, contained antimony           83100
# 4   Plant production, arsenic trioxide or calculat...         60100.0
# ..                                                ...             ...
# 86                                    Mine production             516
# 87                      Mine production, wollastonite         1120000
# 88                          Mine production, zeolites        900000.0
# 89  Mine production, zinc content of concentrates ...           12500
# 90  Zirconium ores and zircon concentrates, mine p...            1440
#
#    Production_2023         Unit       Mineral
# 0          1300000   t_est_2022     abrasives
# 1          1000000   t_est_2022     abrasives
# 2          70000.0      kt_2022      aluminum
# 3            83000       t_2022      antimony
# 4          60000.0       t_2022       arsenic
# ..             ...          ...           ...
# 86             500      kt_2022   vermiculite
# 87         1100000   t_est_2022  wollastonite
# 88       1100000.0   t_est_2022      zeolites
# 89           12000      kt_2022          zinc
# 90            1600  kt_est_2022     zirconium
#
# [91 rows x 7 columns]

# %%
df_iea_usgs = df_usgs_world[df_usgs_world["Mineral"].isin(etm_iea)]
df_iea_usgs
# Out:
#       Source                                     Country  \
# 2   MCS 2024                       World total (rounded)
# 4    MCS2024                       World total (rounded)
# 11   MCS2024                                 World total
# 13   MCS2024                       World total (rounded)
# 16   MCS2024                       World total (rounded)
# 20   MCS2024                       World total (rounded)
# 21   MCS2024                       World total (rounded)
# 22   MCS2024                       World total (rounded)
# 32   MCS2024                       World total (rounded)
# 37   MCS2024                       World total (rounded)
# 40   MCS2024                       World total (rounded)
# 43   MCS2024                       World total (rounded)
# 45   MCS2024                       World total (rounded)
# 46   MCS2024                       World total (rounded)
# 52   MCS2024                       World total (rounded)
# 53   MCS2024                       World total (rounded)
# 59   MCS2024                       World total (rounded)
# 60   MCS2024                       World total (rounded)
# 66   MCS2024                       World total (rounded)
# 67   MCS2024                       World total (rounded)
# 68   MCS2024                       World total (rounded)
# 69   MCS2024                       World total (rounded)
# 78   MCS2024                       World total (rounded)
# 79   MCS2024             World total (ilmenite, rounded)
# 80   MCS2024               World total (rutile, rounded)
# 81   MCS2024  World total (ilmenite and rutile, rounded)
# 82   MCS2024                       World total (rounded)
# 85   MCS2024                       World total (rounded)
# 89   MCS2024                       World total (rounded)
# 90   MCS2024                       World total (rounded)
#
#                                                  Type Production_2022  \
# 2                        Smelter production, aluminum         68400.0
# 4   Plant production, arsenic trioxide or calculat...         60100.0
# 11                              boron total all types              XX
# 13                                Refinery production         22600.0
# 16  Mne production, grosss weight, marketable chro...           41900
# 20   Mine production, metric tons of contained cobalt          197000
# 21        Mine production, recoverable copper content         21900.0
# 22                        Refinery production, copper         25900.0
# 32                                 Primary production        610000.0
# 37                          Mine production, graphite         1680000
# 40                        Refinery production, indium           999.0
# 43                      Mine production, lead content          4460.0
# 45                   Mine production, lithium content          146000
# 46                 Mine production, manganese content           19800
# 52              Mine production, contained molybdenum        253000.0
# 53    Mine production - nickel, metric tons contained       3270000.0
# 59                   World mine production: Palladium          203000
# 60                    World mine production: Platinum          174000
# 66            Refinery production, contained selenium            3310
# 67                    mine production, silver content           25600
# 68  Plant production, silicon content of ferrosilicon            5440
# 69                    Plant production, silicon metal            3670
# 78             Refinery production, tellurium content             584
# 79  World total mine production: Ilmenite, titaniu...            8800
# 80  World total mine production: rutile (rounded),...             640
# 81  World total mine production: ilmentite and rut...            9400
# 82                       Mine production, tin content        307000.0
# 85                  Mine production, vanadium content          102000
# 89  Mine production, zinc content of concentrates ...           12500
# 90  Zirconium ores and zircon concentrates, mine p...            1440
#
#    Production_2023         Unit     Mineral
# 2          70000.0      kt_2022    aluminum
# 4          60000.0       t_2022     arsenic
# 11              XX      kt_2022       boron
# 13         23000.0       t_2022     cadmium
# 16           41000      kt_2022    chromium
# 20          230000   t_est_2022      cobalt
# 21         22000.0      kt_2022      copper
# 22         27000.0      kt_2022      copper
# 32        610000.0      kg_2022     gallium
# 37         1600000       t_2022    graphite
# 40           990.0   t_est_2022      indium
# 43          4500.0      kt_2022        lead
# 45          180000       t_2022     lithium
# 46           20000      kt_2022   manganese
# 52        260000.0       t_2022  molybdenum
# 53       3600000.0       t_2022      nickel
# 59          210000      kg_2022    platinum
# 60          180000      kg_2022    platinum
# 66            3600   t_est_2022    selenium
# 67           26000       t_2022      silver
# 68            5200      kt_2022     silicon
# 69            3800      kt_2022     silicon
# 78             640   t_est_2022   tellurium
# 79            8600  kt_est_2022         tin
# 80             560  kt_est_2022         tin
# 81            9200  kt_est_2022         tin
# 82        290000.0   t_est_2022         tin
# 85        100000.0   t_est_2022    vanadium
# 89           12000      kt_2022        zinc
# 90            1600  kt_est_2022   zirconium

# %% [markdown]
# - Production values are not always the same: smelter (ex=aluminum), refinery (ex=indium),
# - No value for boron
# - In platinum, values for palladium and platinum
# - Two values for silicon (silicon content of ferrosilicon vs silicon metal)
# - Four values for tin

# %%
df_iea_usgs.to_csv(r'df_iea_usgs.csv', index=False)

# %% [markdown]
# # Extract WMD data

# %%
df_wmd_2024 = pd.read_excel(folder_path + r'/WMD/6.2. World_Production_of_Mineral_Raw_Materials_by_ Mineral_Raw_Materials.xlsx', sheet_name='ALL')
df_wmd_2024["Commodity"] = df_wmd_2024["Commodity"].str.lower()
df_wmd_2024["Commodity"] = df_wmd_2024["Commodity"].replace({"aluminium": "aluminum"})
df_wmd_2024
# Out:
#       Commodity            Commodity_group  Unit      2018      2019  \
# 0      aluminum         Non-Ferrous Metals  tons  64443051  63230201
# 1      antimony         Non-Ferrous Metals  tons    145002    134659
# 2       arsenic         Non-Ferrous Metals  tons     51737     55243
# 3      asbestos        Industrial Minerals  tons   1237256   1137505
# 4        baryte        Industrial Minerals  tons   9627288   9510043
# ..          ...                        ...   ...       ...       ...
# 62      uranium             Minerals Fuels  tons     64083     64278
# 63     vanadium  Iron & Ferro-Alloy Metals  tons     84947     98723
# 64  vermiculite        Industrial Minerals  tons    438951    424421
# 65         zinc         Non-Ferrous Metals  tons  12252248  12988998
# 66       zircon        Industrial Minerals  tons   1607468   1417320
#
#         2020      2021      2022
# 0   65404146  67049920  68825618
# 1     119911     91920     83031
# 2      52298     54695     56404
# 3    1132268   1302356   1258065
# 4    7841612   8358423   8278342
# ..       ...       ...       ...
# 62     55718     55981     55972
# 63    105776    110269    115271
# 64    416638    456936    502825
# 65  12669413  12843283  12762076
# 66   1249168   1457826   1385984
#
# [67 rows x 8 columns]

# %%
df_iea_wmd = df_wmd_2024[df_wmd_2024["Commodity"].isin(etm_iea)]
df_iea_wmd
# Out:
#      Commodity            Commodity_group  Unit      2018      2019      2020  \
# 0     aluminum         Non-Ferrous Metals  tons  64443051  63230201  65404146
# 2      arsenic         Non-Ferrous Metals  tons     51737     55243     52298
# 9        boron        Industrial Minerals  tons   4492429   4293276   3601490
# 10     cadmium         Non-Ferrous Metals  tons     27173     25089     25564
# 11    chromium  Iron & Ferro-Alloy Metals  tons  15188744  15779216  11969552
# 13      cobalt  Iron & Ferro-Alloy Metals  tons    158317    124425    129651
# 15      copper         Non-Ferrous Metals  tons  20675762  20633412  21074917
# 21     gallium         Non-Ferrous Metals  tons       323       374       304
# 24    graphite        Industrial Minerals  tons   1562542   1605838   1388356
# 27      indium         Non-Ferrous Metals  tons       831       918       943
# 30        lead         Non-Ferrous Metals  tons   4623263   4906459   4727874
# 32     lithium         Non-Ferrous Metals  tons    198967    192108    187000
# 34   manganese  Iron & Ferro-Alloy Metals  tons  19609756  21164890  19618004
# 36  molybdenum  Iron & Ferro-Alloy Metals  tons    270100    277180    284890
# 38      nickel  Iron & Ferro-Alloy Metals  tons   2377719   2690477   2490804
# 46    platinum            Precious Metals  tons    189221    186805    162783
# 52    selenium         Non-Ferrous Metals  tons      3196      3533      3279
# 53      silver            Precious Metals  tons  27677375  28101057  26517217
# 58   tellurium         Non-Ferrous Metals  tons       649       529       459
# 59         tin         Non-Ferrous Metals  tons    316929    294333    277997
# 63    vanadium  Iron & Ferro-Alloy Metals  tons     84947     98723    105776
# 65        zinc         Non-Ferrous Metals  tons  12252248  12988998  12669413
#
#         2021      2022
# 0   67049920  68825618
# 2      54695     56404
# 9    4922770   5346091
# 10     25529     23003
# 11  14721408  15259786
# 13    134692    166030
# 15  21447064  22225410
# 21       431       616
# 24   1662844   1727486
# 27       916      1008
# 30   4600155   4693950
# 32    232576    345829
# 34  20513388  20284488
# 36    271138    265460
# 38   2852212   3248896
# 46    189389    183022
# 52      3733      3735
# 53  26609813  26584338
# 58       742       681
# 59    263576    292351
# 63    110269    115271
# 65  12843283  12762076

# %%
df_iea_wmd.to_csv(r'df_iea_wmd.csv', index=False)

# %% [markdown]
# # Dealing with missing metals

# %%
missing_metals = [
'dysprosium', # REE
'ferromanganese',
'ferronickel',
'iridium', # PGM
'neodymium', # REE
'praseodymium', # REE
'terbium' # REE 
]
